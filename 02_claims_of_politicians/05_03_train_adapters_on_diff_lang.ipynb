# %%
from polyglot.text import Text

import pandas as pd
import numpy as np

from tqdm import tqdm
tqdm.pandas()
from pandarallel import pandarallel
pandarallel.initialize(nb_workers=7,progress_bar=True)

from parallelbar import progress_map

from utils import *

from nltk import ngrams
import nltk

import scipy
from sklearn.model_selection import cross_validate

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier, VotingClassifier
import xgboost as xgb

from sklearn.metrics import (
    accuracy_score, 
    f1_score, 
    recall_score,
    precision_score,
    roc_auc_score, confusion_matrix, roc_curve, classification_report
)

from sentence_transformers import SentenceTransformer

import random

from datasets import Dataset, DatasetDict
import pandas as pd
import torch

from transformers import AutoTokenizer

from transformers import BertAdapterModel, BertConfig

from transformers import PfeifferConfig

from transformers import TrainingArguments, AdapterTrainer, EvalPrediction
from sklearn.metrics import accuracy_score, f1_score, mean_absolute_error

torch.cuda.is_available()
# Out:
# INFO: Pandarallel will run on 7 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# /home/marek/anaconda3/envs/nlp/lib/python3.9/site-packages/huggingface_hub/snapshot_download.py:6: FutureWarning: snapshot_download.py has been made private and will no longer be available from version 0.11. Please use `from huggingface_hub import snapshot_download` to import the only public function in this module. Other members of the file may be changed without a deprecation notice.
#   warnings.warn(
# True

# %% [markdown]
# ## POS CZ data

# %%
if False:
    df_cz_cz = pd.read_csv('../datasets/demagog_nlp_cz/converted-exp-CZ.tsv', sep='\t')

    df_cz_cz['text_clean'] = df_cz_cz['statementText'].apply(lambda x: clean_przyp(x))

    tasks = df_cz_cz['text_clean'].values.tolist()
    result = progress_map(extract_features_cz, tasks, n_cpu=7, chunk_size=1, core_progress=True)
    
    df_cz_cz['TEXT_POS'] = result

    df_cz_cz['TEXT_POS'] = df_cz_cz['TEXT_POS'].str.join(" ")
    
    df_cz_cz.to_csv('../datasets/ready2use/fake_news_features_cz_CZ.csv', sep=';', index=False, encoding='utf8')
else:
    df_cz_cz = pd.read_csv('../datasets/ready2use/fake_news_features_cz_CZ.csv', sep=';')

# %%
df_cz_cz.shape
# Out:
# (9082, 10)

# %% [markdown]
# ### The same code for SK data

# %%
if False:
    df_cz_sk = pd.read_csv('../datasets/demagog_nlp_cz/converted-exp-SK.tsv', sep='\t')

    df_cz_sk['text_clean'] = df_cz_sk['statementText'].apply(lambda x: clean_przyp(x))

    tasks = df_cz_sk['text_clean'].values.tolist()
    result = progress_map(extract_features_cz, tasks, n_cpu=7, chunk_size=1, core_progress=True)
    
    df_cz_sk['TEXT_POS'] = result

    df_cz_sk['TEXT_POS'] = df_cz_sk['TEXT_POS'].str.join(" ")
    
    df_cz_sk.to_csv('../datasets/ready2use/fake_news_features_cz_SK.csv', sep=';', index=False, encoding='utf8')
else:
    df_cz_sk = pd.read_csv('../datasets/ready2use/fake_news_features_cz_SK.csv', sep=';')

# %%
df_cz_sk.shape
# Out:
# (12554, 10)

# %%
df_cz = pd.concat([df_cz_sk, df_cz_sk])
df_cz.shape
# Out:
# (25108, 10)

# %%
df_cz['statementState'] = df_cz['statementState'].str.strip()

df_cz = df_cz[ df_cz['statementState'] != 'MISLEADING' ]
df_cz = df_cz[ df_cz['statementState'] != 'UNVERIFIABLE' ]
df_cz = df_cz[ df_cz['statementState'] != 'null' ]

df_cz = df_cz.reset_index(drop=True)

df_cz['assestment'] = df_cz['statementState'].replace({
    'FALSE' : 0,
#     'Manipulacja' : 1,
    'TRUE' : 1
}).astype(int)

# %%
df_cz['assestment'].value_counts()
# Out:
# 1    15974
# 0     3340
# Name: assestment, dtype: int64

# %% [markdown]
# ## POS ENG data

# %%
df_en = pd.read_csv('../datasets/politifact/politifact.csv', sep=',', index_col=0)

df_en.loc[:, 'fact'] = df_en['fact'].replace({
    'half-true' : 'true',
    'mostly-true' : 'true',
    'barely-true' : 'false',
    'pants-fire' : 'false',
})

df_en = df_en[df_en['fact'].isin(['true', 'false'])]

# %%
df_en.shape
# Out:
# (19151, 11)

# %%
df_en = df_en[['sources_quote', 'fact']]
df_en.columns  = [
    'statement',
    'label'
]

df_en['text_clean'] = df_en['statement'].apply(lambda x: clean_przyp(x))

df_en['assestment'] = df_en['label'].replace({
    'false' : 0,
#     'Manipulacja' : 1,
    'true' : 1
}).astype(int)

# %% [markdown]
# ## Use EN/CZ data as training

# %%
df_all = pd.concat([df_en[['assestment', 'text_clean']], 
                    df_cz[['assestment', 'text_clean']]])

# %%
df_all = df_cz[['assestment', 'text_clean']]

# %%
df_all['assestment'].value_counts()
# Out:
# 1    15974
# 0     3340
# Name: assestment, dtype: int64

# %%
df_all['sentence'] = df_all['text_clean'].apply(lambda x: x.replace('\n',' ').strip())
df_all['labels'] = df_all['assestment'].astype(int)

df_all = df_all.sample(frac=1, random_state=111)

df_all.shape
# Out:
# /tmp/ipykernel_1266322/3004308602.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all['sentence'] = df_all['text_clean'].apply(lambda x: x.replace('\n',' ').strip())
# /tmp/ipykernel_1266322/3004308602.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all['labels'] = df_all['assestment'].astype(int)
# (19314, 4)

# %% [markdown]
# ### Load pl data

# %%
df = pd.read_csv('../datasets/ready2use/text_celan_pl_dataset.csv',
                 index_col=0,
                 sep=';',header=None,names='sentence labels'.split())

df['sentence'] = df['sentence'].apply(lambda x: x.replace('\n',' ').strip())
df['labels'] = df['labels'].astype(int)

df = df.sample(frac=1, random_state=111)

df.shape
# Out:
# (6542, 2)

# %%
model_name = 'DeepPavlov/bert-base-bg-cs-pl-ru-cased'

# %%
tok = AutoTokenizer.from_pretrained(model_name)
# Out:
# Downloading tokenizer_config.json:   0%|          | 0.00/24.0 [00:00<?, ?B/s]
# Downloading config.json:   0%|          | 0.00/642 [00:00<?, ?B/s]
# Downloading vocab.txt:   0%|          | 0.00/1.13M [00:00<?, ?B/s]
# Downloading special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
labels = sorted(set(df_all['labels']))
num_labels = len(labels)
label2id = dict(zip(labels,range(num_labels)))
id2label = {v: k for k, v in label2id.items()}

def encode_batch(batch):
    """Encodes a batch of input data using the model tokenizer."""
    batch['labels'] = np.array(batch['labels'])
    return tok(text=batch['sentence'], max_length=64, truncation=True, padding="max_length")

# %%
config = BertConfig.from_pretrained(
    model_name,
    num_labels=num_labels
)

adapter_config = PfeifferConfig()


training_args = TrainingArguments(
    remove_unused_columns=False, # ensure the dataset labels are properly passed to the model
    
    fp16=True,
    learning_rate=1e-4,
    num_train_epochs=10,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=32,
    gradient_accumulation_steps=1,
    max_grad_norm=1.0,
    label_smoothing_factor=0.0,
    weight_decay=0.05,
    warmup_steps=600,
    output_dir="./training_output",
    overwrite_output_dir=True,
    
#     logging_strategy="no"
    
    logging_steps=200,
    logging_first_step=False,
    logging_dir='./tb_logs',
    evaluation_strategy='steps',
    report_to='tensorboard',
    save_steps=200
)

def compute_accuracy_f1score(p: EvalPrediction):
    preds = [id2label[pred_id] for pred_id in np.argmax(p.predictions, axis=1)]
    target_labels = [id2label[label_id] for label_id in p.label_ids]
    return {"accuracy": accuracy_score(target_labels,preds),
           "f1score": f1_score(target_labels,preds)}

# %%
ds = DatasetDict()
ds['train'] = Dataset.from_pandas(df_all)
ds['valid'] = Dataset.from_pandas(df)


ds = ds.map(encode_batch, batched=True, batch_size=len(ds['train']))
ds.set_format(type="torch", columns=["input_ids", "attention_mask", "labels"])


model = BertAdapterModel.from_pretrained(model_name, config=config).to('cuda')

adapter_name='fake_news_multilang_0'

model.add_adapter(adapter_name,config=adapter_config)
model.add_classification_head(
    adapter_name,
    id2label=id2label,
    num_labels=num_labels
  )

model.train_adapter(adapter_name)


trainer = AdapterTrainer(
    model=model,
    args=training_args,
    train_dataset=ds["train"],
    eval_dataset=ds["valid"],
    compute_metrics=compute_accuracy_f1score,
)

trainer.train()
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/681M [00:00<?, ?B/s]
# Some weights of the model checkpoint at DeepPavlov/bert-base-bg-cs-pl-ru-cased were not used when initializing BertAdapterModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.bias', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertAdapterModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertAdapterModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Using cuda_amp half precision backend
# /home/marek/anaconda3/envs/nlp/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 19314
#   Num Epochs = 10
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 24150
#     <div>
#
#       <progress value='24150' max='24150' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [24150/24150 45:45, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>200</td>
#       <td>0.562400</td>
#       <td>0.861352</td>
#       <td>0.474320</td>
#       <td>0.643442</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.465900</td>
#       <td>1.057838</td>
#       <td>0.474320</td>
#       <td>0.643442</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.473700</td>
#       <td>1.098155</td>
#       <td>0.474320</td>
#       <td>0.643442</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.464100</td>
#       <td>1.000463</td>
#       <td>0.474320</td>
#       <td>0.643442</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.456500</td>
#       <td>1.116927</td>
#       <td>0.474320</td>
#       <td>0.643442</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.445000</td>
#       <td>0.993393</td>
#       <td>0.474473</td>
#       <td>0.643509</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.457700</td>
#       <td>1.007912</td>
#       <td>0.474320</td>
#       <td>0.643442</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.453400</td>
#       <td>1.161575</td>
#       <td>0.474473</td>
#       <td>0.643509</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.445500</td>
#       <td>1.250108</td>
#       <td>0.474473</td>
#       <td>0.643509</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.473900</td>
#       <td>1.099069</td>
#       <td>0.474320</td>
#       <td>0.643442</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>0.472100</td>
#       <td>1.234140</td>
#       <td>0.474320</td>
#       <td>0.643442</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.476700</td>
#       <td>1.134879</td>
#       <td>0.474320</td>
#       <td>0.643442</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>0.439300</td>
#       <td>1.183724</td>
#       <td>0.474320</td>
#       <td>0.643442</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>0.437500</td>
#       <td>1.165806</td>
#       <td>0.474167</td>
#       <td>0.643228</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.473300</td>
#       <td>1.023044</td>
#       <td>0.469275</td>
#       <td>0.637200</td>
#     </tr>
#     <tr>
#       <td>3200</td>
#       <td>0.448100</td>
#       <td>1.089323</td>
#       <td>0.474473</td>
#       <td>0.643509</td>
#     </tr>
#     <tr>
#       <td>3400</td>
#       <td>0.479200</td>
#       <td>1.377360</td>
#       <td>0.474473</td>
#       <td>0.643509</td>
#     </tr>
#     <tr>
#       <td>3600</td>
#       <td>0.469800</td>
#       <td>1.247034</td>
#       <td>0.474473</td>
#       <td>0.643509</td>
#     </tr>
#     <tr>
#       <td>3800</td>
#       <td>0.466900</td>
#       <td>1.023676</td>
#       <td>0.474167</td>
#       <td>0.643079</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.432400</td>
#       <td>1.261028</td>
#       <td>0.474167</td>
#       <td>0.643228</td>
#     </tr>
#     <tr>
#       <td>4200</td>
#       <td>0.425300</td>
#       <td>1.155975</td>
#       <td>0.473555</td>
#       <td>0.642368</td>
#     </tr>
#     <tr>
#       <td>4400</td>
#       <td>0.433500</td>
#       <td>1.225143</td>
#       <td>0.474320</td>
#       <td>0.643442</td>
#     </tr>
#     <tr>
#       <td>4600</td>
#       <td>0.451100</td>
#       <td>1.135342</td>
#       <td>0.474320</td>
#       <td>0.642850</td>
#     </tr>
#     <tr>
#       <td>4800</td>
#       <td>0.443900</td>
#       <td>1.338040</td>
#       <td>0.474473</td>
#       <td>0.643509</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.423800</td>
#       <td>1.341804</td>
#       <td>0.472638</td>
#       <td>0.641148</td>
#     </tr>
#     <tr>
#       <td>5200</td>
#       <td>0.404900</td>
#       <td>1.131425</td>
#       <td>0.467900</td>
#       <td>0.634847</td>
#     </tr>
#     <tr>
#       <td>5400</td>
#       <td>0.424200</td>
#       <td>1.253465</td>
#       <td>0.469275</td>
#       <td>0.637578</td>
#     </tr>
#     <tr>
#       <td>5600</td>
#       <td>0.411300</td>
#       <td>1.365767</td>
#       <td>0.471110</td>
#       <td>0.639358</td>
#     </tr>
#     <tr>
#       <td>5800</td>
#       <td>0.442700</td>
#       <td>1.339502</td>
#       <td>0.466524</td>
#       <td>0.632941</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.444800</td>
#       <td>1.173210</td>
#       <td>0.465760</td>
#       <td>0.631601</td>
#     </tr>
#     <tr>
#       <td>6200</td>
#       <td>0.440900</td>
#       <td>1.091713</td>
#       <td>0.463314</td>
#       <td>0.620063</td>
#     </tr>
#     <tr>
#       <td>6400</td>
#       <td>0.462000</td>
#       <td>1.071413</td>
#       <td>0.445430</td>
#       <td>0.593456</td>
#     </tr>
#     <tr>
#       <td>6600</td>
#       <td>0.433200</td>
#       <td>1.240386</td>
#       <td>0.466830</td>
#       <td>0.632687</td>
#     </tr>
#     <tr>
#       <td>6800</td>
#       <td>0.419000</td>
#       <td>1.409587</td>
#       <td>0.468817</td>
#       <td>0.635782</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.400300</td>
#       <td>1.967250</td>
#       <td>0.474014</td>
#       <td>0.643087</td>
#     </tr>
#     <tr>
#       <td>7200</td>
#       <td>0.416100</td>
#       <td>1.329590</td>
#       <td>0.469887</td>
#       <td>0.638147</td>
#     </tr>
#     <tr>
#       <td>7400</td>
#       <td>0.395100</td>
#       <td>1.257328</td>
#       <td>0.457352</td>
#       <td>0.614884</td>
#     </tr>
#     <tr>
#       <td>7600</td>
#       <td>0.378400</td>
#       <td>1.411595</td>
#       <td>0.445124</td>
#       <td>0.594956</td>
#     </tr>
#     <tr>
#       <td>7800</td>
#       <td>0.383700</td>
#       <td>1.447335</td>
#       <td>0.462550</td>
#       <td>0.617743</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.379600</td>
#       <td>1.407116</td>
#       <td>0.464231</td>
#       <td>0.623240</td>
#     </tr>
#     <tr>
#       <td>8200</td>
#       <td>0.416400</td>
#       <td>1.159219</td>
#       <td>0.452920</td>
#       <td>0.596641</td>
#     </tr>
#     <tr>
#       <td>8400</td>
#       <td>0.394400</td>
#       <td>1.357297</td>
#       <td>0.451238</td>
#       <td>0.598972</td>
#     </tr>
#     <tr>
#       <td>8600</td>
#       <td>0.375600</td>
#       <td>1.459199</td>
#       <td>0.464384</td>
#       <td>0.628025</td>
#     </tr>
#     <tr>
#       <td>8800</td>
#       <td>0.379500</td>
#       <td>1.302247</td>
#       <td>0.464078</td>
#       <td>0.626067</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.422100</td>
#       <td>1.162716</td>
#       <td>0.433812</td>
#       <td>0.568298</td>
#     </tr>
#     <tr>
#       <td>9200</td>
#       <td>0.361000</td>
#       <td>1.603042</td>
#       <td>0.461480</td>
#       <td>0.621142</td>
#     </tr>
#     <tr>
#       <td>9400</td>
#       <td>0.395400</td>
#       <td>1.631384</td>
#       <td>0.450321</td>
#       <td>0.599108</td>
#     </tr>
#     <tr>
#       <td>9600</td>
#       <td>0.390600</td>
#       <td>1.206726</td>
#       <td>0.453684</td>
#       <td>0.588723</td>
#     </tr>
#     <tr>
#       <td>9800</td>
#       <td>0.347200</td>
#       <td>1.764622</td>
#       <td>0.454448</td>
#       <td>0.600917</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.373500</td>
#       <td>1.533663</td>
#       <td>0.454754</td>
#       <td>0.608924</td>
#     </tr>
#     <tr>
#       <td>10200</td>
#       <td>0.350000</td>
#       <td>1.594108</td>
#       <td>0.457047</td>
#       <td>0.609585</td>
#     </tr>
#     <tr>
#       <td>10400</td>
#       <td>0.366200</td>
#       <td>1.808868</td>
#       <td>0.459951</td>
#       <td>0.617434</td>
#     </tr>
#     <tr>
#       <td>10600</td>
#       <td>0.345500</td>
#       <td>1.801626</td>
#       <td>0.445124</td>
#       <td>0.591860</td>
#     </tr>
#     <tr>
#       <td>10800</td>
#       <td>0.358300</td>
#       <td>1.733128</td>
#       <td>0.457047</td>
#       <td>0.609499</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.356000</td>
#       <td>1.720400</td>
#       <td>0.455824</td>
#       <td>0.607237</td>
#     </tr>
#     <tr>
#       <td>11200</td>
#       <td>0.338700</td>
#       <td>1.881746</td>
#       <td>0.458728</td>
#       <td>0.618796</td>
#     </tr>
#     <tr>
#       <
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-200
# Configuration saved in ./training_output/checkpoint-200/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-200/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-200/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-200/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-200/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-200/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-400
# Configuration saved in ./training_output/checkpoint-400/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-400/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-400/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-400/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-400/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-400/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-600
# Configuration saved in ./training_output/checkpoint-600/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-600/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-600/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-600/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-600/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-600/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-800
# Configuration saved in ./training_output/checkpoint-800/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-800/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-800/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-800/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-800/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-800/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-1000
# Configuration saved in ./training_output/checkpoint-1000/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-1000/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-1000/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-1000/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-1000/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-1000/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-1200
# Configuration saved in ./training_output/checkpoint-1200/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-1200/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-1200/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-1200/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-1200/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-1200/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-1400
# Configuration saved in ./training_output/checkpoint-1400/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-1400/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-1400/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-1400/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-1400/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-1400/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-1600
# Configuration saved in ./training_output/checkpoint-1600/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-1600/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-1600/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-1600/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-1600/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-1600/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-1800
# Configuration saved in ./training_output/checkpoint-1800/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-1800/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-1800/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-1800/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-1800/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-1800/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-2000
# Configuration saved in ./training_output/checkpoint-2000/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-2000/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-2000/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-2000/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-2000/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-2000/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-2200
# Configuration saved in ./training_output/checkpoint-2200/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-2200/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-2200/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-2200/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-2200/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-2200/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-2400
# Configuration saved in ./training_output/checkpoint-2400/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-2400/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-2400/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-2400/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-2400/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-2400/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-2600
# Configuration saved in ./training_output/checkpoint-2600/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-2600/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-2600/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-2600/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-2600/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-2600/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-2800
# Configuration saved in ./training_output/checkpoint-2800/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-2800/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-2800/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-2800/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-2800/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-2800/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-3000
# Configuration saved in ./training_output/checkpoint-3000/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-3000/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-3000/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-3000/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-3000/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-3000/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-3200
# Configuration saved in ./training_output/checkpoint-3200/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-3200/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-3200/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-3200/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-3200/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-3200/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-3400
# Configuration saved in ./training_output/checkpoint-3400/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-3400/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-3400/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-3400/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-3400/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-3400/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-3600
# Configuration saved in ./training_output/checkpoint-3600/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-3600/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-3600/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-3600/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-3600/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-3600/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-3800
# Configuration saved in ./training_output/checkpoint-3800/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-3800/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-3800/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-3800/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-3800/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-3800/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-4000
# Configuration saved in ./training_output/checkpoint-4000/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-4000/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-4000/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-4000/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-4000/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-4000/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-4200
# Configuration saved in ./training_output/checkpoint-4200/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-4200/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-4200/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-4200/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-4200/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-4200/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-4400
# Configuration saved in ./training_output/checkpoint-4400/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-4400/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-4400/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-4400/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-4400/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-4400/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-4600
# Configuration saved in ./training_output/checkpoint-4600/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-4600/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-4600/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-4600/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-4600/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-4600/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-4800
# Configuration saved in ./training_output/checkpoint-4800/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-4800/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-4800/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-4800/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-4800/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-4800/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-5000
# Configuration saved in ./training_output/checkpoint-5000/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-5000/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-5000/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-5000/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-5000/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-5000/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-5200
# Configuration saved in ./training_output/checkpoint-5200/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-5200/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-5200/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-5200/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-5200/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-5200/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-5400
# Configuration saved in ./training_output/checkpoint-5400/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-5400/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-5400/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-5400/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-5400/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-5400/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-5600
# Configuration saved in ./training_output/checkpoint-5600/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-5600/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-5600/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-5600/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-5600/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-5600/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-5800
# Configuration saved in ./training_output/checkpoint-5800/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-5800/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-5800/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-5800/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-5800/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-5800/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-6000
# Configuration saved in ./training_output/checkpoint-6000/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-6000/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-6000/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-6000/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-6000/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-6000/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-6200
# Configuration saved in ./training_output/checkpoint-6200/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-6200/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-6200/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-6200/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-6200/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-6200/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-6400
# Configuration saved in ./training_output/checkpoint-6400/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-6400/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-6400/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-6400/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-6400/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-6400/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-6600
# Configuration saved in ./training_output/checkpoint-6600/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-6600/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-6600/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-6600/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-6600/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-6600/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-6800
# Configuration saved in ./training_output/checkpoint-6800/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-6800/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-6800/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-6800/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-6800/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-6800/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-7000
# Configuration saved in ./training_output/checkpoint-7000/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-7000/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-7000/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-7000/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-7000/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-7000/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-7200
# Configuration saved in ./training_output/checkpoint-7200/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-7200/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-7200/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-7200/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-7200/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-7200/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-7400
# Configuration saved in ./training_output/checkpoint-7400/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-7400/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-7400/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-7400/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-7400/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-7400/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-7600
# Configuration saved in ./training_output/checkpoint-7600/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-7600/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-7600/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-7600/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-7600/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-7600/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-7800
# Configuration saved in ./training_output/checkpoint-7800/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-7800/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-7800/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-7800/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-7800/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-7800/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-8000
# Configuration saved in ./training_output/checkpoint-8000/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-8000/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-8000/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-8000/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-8000/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-8000/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-8200
# Configuration saved in ./training_output/checkpoint-8200/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-8200/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-8200/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-8200/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-8200/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-8200/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-8400
# Configuration saved in ./training_output/checkpoint-8400/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-8400/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-8400/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-8400/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-8400/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-8400/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-8600
# Configuration saved in ./training_output/checkpoint-8600/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-8600/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-8600/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-8600/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-8600/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-8600/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-8800
# Configuration saved in ./training_output/checkpoint-8800/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-8800/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-8800/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-8800/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-8800/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-8800/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-9000
# Configuration saved in ./training_output/checkpoint-9000/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-9000/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-9000/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-9000/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-9000/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-9000/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-9200
# Configuration saved in ./training_output/checkpoint-9200/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-9200/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-9200/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-9200/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-9200/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-9200/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-9400
# Configuration saved in ./training_output/checkpoint-9400/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-9400/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-9400/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-9400/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-9400/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-9400/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-9600
# Configuration saved in ./training_output/checkpoint-9600/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-9600/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-9600/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-9600/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-9600/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-9600/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-9800
# Configuration saved in ./training_output/checkpoint-9800/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-9800/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-9800/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-9800/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-9800/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-9800/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-10000
# Configuration saved in ./training_output/checkpoint-10000/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-10000/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-10000/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-10000/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-10000/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-10000/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-10200
# Configuration saved in ./training_output/checkpoint-10200/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-10200/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-10200/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-10200/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-10200/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-10200/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-10400
# Configuration saved in ./training_output/checkpoint-10400/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-10400/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-10400/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-10400/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-10400/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-10400/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-10600
# Configuration saved in ./training_output/checkpoint-10600/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-10600/fake_news_multilang_0/pytorch_adapter.bin
# ...
# Configuration saved in ./training_output/checkpoint-19800/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-19800/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-20000
# Configuration saved in ./training_output/checkpoint-20000/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-20000/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-20000/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-20000/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-20000/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-20000/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-20200
# Configuration saved in ./training_output/checkpoint-20200/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-20200/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-20200/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-20200/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-20200/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-20200/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-20400
# Configuration saved in ./training_output/checkpoint-20400/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-20400/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-20400/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-20400/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-20400/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-20400/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-20600
# Configuration saved in ./training_output/checkpoint-20600/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-20600/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-20600/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-20600/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-20600/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-20600/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-20800
# Configuration saved in ./training_output/checkpoint-20800/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-20800/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-20800/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-20800/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-20800/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-20800/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-21000
# Configuration saved in ./training_output/checkpoint-21000/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-21000/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-21000/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-21000/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-21000/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-21000/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-21200
# Configuration saved in ./training_output/checkpoint-21200/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-21200/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-21200/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-21200/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-21200/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-21200/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-21400
# Configuration saved in ./training_output/checkpoint-21400/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-21400/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-21400/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-21400/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-21400/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-21400/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-21600
# Configuration saved in ./training_output/checkpoint-21600/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-21600/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-21600/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-21600/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-21600/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-21600/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-21800
# Configuration saved in ./training_output/checkpoint-21800/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-21800/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-21800/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-21800/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-21800/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-21800/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-22000
# Configuration saved in ./training_output/checkpoint-22000/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-22000/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-22000/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-22000/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-22000/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-22000/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-22200
# Configuration saved in ./training_output/checkpoint-22200/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-22200/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-22200/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-22200/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-22200/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-22200/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-22400
# Configuration saved in ./training_output/checkpoint-22400/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-22400/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-22400/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-22400/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-22400/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-22400/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-22600
# Configuration saved in ./training_output/checkpoint-22600/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-22600/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-22600/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-22600/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-22600/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-22600/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-22800
# Configuration saved in ./training_output/checkpoint-22800/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-22800/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-22800/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-22800/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-22800/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-22800/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-23000
# Configuration saved in ./training_output/checkpoint-23000/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-23000/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-23000/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-23000/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-23000/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-23000/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-23200
# Configuration saved in ./training_output/checkpoint-23200/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-23200/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-23200/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-23200/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-23200/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-23200/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-23400
# Configuration saved in ./training_output/checkpoint-23400/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-23400/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-23400/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-23400/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-23400/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-23400/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-23600
# Configuration saved in ./training_output/checkpoint-23600/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-23600/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-23600/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-23600/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-23600/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-23600/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-23800
# Configuration saved in ./training_output/checkpoint-23800/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-23800/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-23800/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-23800/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-23800/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-23800/fake_news_multilang_0/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
# Saving model checkpoint to ./training_output/checkpoint-24000
# Configuration saved in ./training_output/checkpoint-24000/fake_news_multilang_0/adapter_config.json
# Module weights saved in ./training_output/checkpoint-24000/fake_news_multilang_0/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-24000/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-24000/fake_news_multilang_0/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-24000/fake_news_multilang_0/head_config.json
# Module weights saved in ./training_output/checkpoint-24000/fake_news_multilang_0/pytorch_model_head.bin
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=24150, training_loss=0.3441591379706657, metrics={'train_runtime': 2745.6658, 'train_samples_per_second': 70.344, 'train_steps_per_second': 8.796, 'total_flos': 6462303707520000.0, 'train_loss': 0.3441591379706657, 'epoch': 10.0})

# %%
eval_out = trainer.evaluate()

print('Acc', eval_out['eval_accuracy'])
print('F1', eval_out['eval_f1score'])
# Out:
# ***** Running Evaluation *****
#   Num examples = 6542
#   Batch size = 32
#     <div>
#
#       <progress value='205' max='205' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [205/205 00:10]
#     </div>
# Acc 0.4544481809844084
# F1 0.6027824151363383
